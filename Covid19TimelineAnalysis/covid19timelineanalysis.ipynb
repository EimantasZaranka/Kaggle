# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/covid19-timeline-analysis/owid-covid-data.csv

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (5.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly) (7.0.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from plotly) (1.15.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import plotly.graph_objs as go
import plotly.express as px

# %% [markdown]
# # Before I Start
#
# This time I will be working with ***plotly*** instead of ***seaborn***
#
# ## Assumptions
#
# - There should be two waves of Covid outburst one around april of 2020. The second one at the end of 2020/ beginning of 2021.
# - Testing numbers should be increasing because of introduction of green pass and restrictions not having it.
# - Vaccination should be ramping up at the start of it and got lower around summer because of holiday season.
# - Countries with better gdp per capita and younger median age should be suffering less from covid
#
# ## Questions I Want to Answer
#
# 0. What is total number of Covid cases, tests made and vaccinated people?
# 1. How dense population is in every country?
# 2. What is Median age in every country and how does it look compared to others?
# 3. How covid progressed by total cases, new cases, total deaths, new deaths?
# 4. How testing rate changed during the pandemic?
# 5. How test per case changed in Lithuania, Japan and USA.
# 6. Vaccination progess, how it change?
# 7. How strictly goverments responded with restrictions?
# 8. Does countries that have more smoking people suffer more from covid?
# 9. How gdp_per_capita and meadian age correlates with total cases?

# %% [markdown]
# # Basic Insights on Data

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('../input/covid19-timeline-analysis/owid-covid-data.csv')
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Basic information about the structure of dataset

# %%
df.shape
# Out:
# (103143, 60)

# %%
len(df.iso_code.unique())
# Out:
# 231

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103143 entries, 0 to 103142
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               103143 non-null  object
#  1   continent                              98330 non-null   object
#  2   location                               103143 non-null  object
#  3   date                                   103143 non-null  object
#  4   total_cases                            99197 non-null   float64
#  5   new_cases                              99194 non-null   float64
#  6   new_cases_smoothed                     98184 non-null   float64
#  7   total_deaths                           88953 non-null   float64
#  8   new_deaths                             89109 non-null   float64
#  9   new_deaths_smoothed                    98184 non-null   float64
#  10  total_cases_per_million                98670 non-null   float64
#  11  new_cases_per_million                  98667 non-null   float64
#  12  new_cases_smoothed_per_million         97662 non-null   float64
#  13  total_deaths_per_million               88439 non-null   float64
#  14  new_deaths_per_million                 88595 non-null   float64
#  15  new_deaths_smoothed_per_million        97662 non-null   float64
#  16  reproduction_rate                      82967 non-null   float64
#  17  icu_patients                           10695 non-null   float64
#  18  icu_patients_per_million               10695 non-null   float64
#  19  hosp_patients                          12921 non-null   float64
#  20  hosp_patients_per_million              12921 non-null   float64
#  21  weekly_icu_admissions                  951 non-null     float64
#  22  weekly_icu_admissions_per_million      951 non-null     float64
#  23  weekly_hosp_admissions                 1615 non-null    float64
#  24  weekly_hosp_admissions_per_million     1615 non-null    float64
#  25  new_tests                              46155 non-null   float64
#  26  total_tests                            45813 non-null   float64
#  27  total_tests_per_thousand               45813 non-null   float64
#  28  new_tests_per_thousand                 46155 non-null   float64
#  29  new_tests_smoothed                     53734 non-null   float64
#  30  new_tests_smoothed_per_thousand        53734 non-null   float64
#  31  positive_rate                          50221 non-null   float64
#  32  tests_per_case                         49591 non-null   float64
#  33  tests_units                            55445 non-null   object
#  34  total_vaccinations                     18418 non-null   float64
#  35  people_vaccinated                      17512 non-null   float64
#  36  people_fully_vaccinated                14659 non-null   float64
#  37  new_vaccinations                       15370 non-null   float64
#  38  new_vaccinations_smoothed              32003 non-null   float64
#  39  total_vaccinations_per_hundred         18418 non-null   float64
#  40  people_vaccinated_per_hundred          17512 non-null   float64
#  41  people_fully_vaccinated_per_hundred    14659 non-null   float64
#  42  new_vaccinations_smoothed_per_million  32003 non-null   float64
#  43  stringency_index                       86245 non-null   float64
#  44  population                             102451 non-null  float64
#  45  population_density                     95774 non-null   float64
#  46  median_age                             92014 non-null   float64
#  47  aged_65_older                          90982 non-null   float64
#  48  aged_70_older                          91506 non-null   float64
#  49  gdp_per_capita                         92397 non-null   float64
#  50  extreme_poverty                        62295 non-null   float64
#  51  cardiovasc_death_rate                  92382 non-null   float64
#  52  diabetes_prevalence                    94822 non-null   float64
#  53  female_smokers                         72229 non-null   float64
#  54  male_smokers                           71176 non-null   float64
#  55  handwashing_facilities                 46418 non-null   float64
#  56  hospital_beds_per_thousand             84121 non-null   float64
#  57  life_expectancy                        97916 non-null   float64
#  58  human_development_index                92508 non-null   float64
#  59  excess_mortality                       3624 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 47.2+ MB

# %%
df.isna().sum()
# Out:
# iso_code                                      0
# continent                                  4813
# location                                      0
# date                                          0
# total_cases                                3946
# new_cases                                  3949
# new_cases_smoothed                         4959
# total_deaths                              14190
# new_deaths                                14034
# new_deaths_smoothed                        4959
# total_cases_per_million                    4473
# new_cases_per_million                      4476
# new_cases_smoothed_per_million             5481
# total_deaths_per_million                  14704
# new_deaths_per_million                    14548
# new_deaths_smoothed_per_million            5481
# reproduction_rate                         20176
# icu_patients                              92448
# icu_patients_per_million                  92448
# hosp_patients                             90222
# hosp_patients_per_million                 90222
# weekly_icu_admissions                    102192
# weekly_icu_admissions_per_million        102192
# weekly_hosp_admissions                   101528
# weekly_hosp_admissions_per_million       101528
# new_tests                                 56988
# total_tests                               57330
# total_tests_per_thousand                  57330
# new_tests_per_thousand                    56988
# new_tests_smoothed                        49409
# new_tests_smoothed_per_thousand           49409
# positive_rate                             52922
# tests_per_case                            53552
# tests_units                               47698
# total_vaccinations                        84725
# people_vaccinated                         85631
# people_fully_vaccinated                   88484
# new_vaccinations                          87773
# new_vaccinations_smoothed                 71140
# total_vaccinations_per_hundred            84725
# people_vaccinated_per_hundred             85631
# people_fully_vaccinated_per_hundred       88484
# new_vaccinations_smoothed_per_million     71140
# stringency_index                          16898
# population                                  692
# population_density                         7369
# median_age                                11129
# aged_65_older                             12161
# aged_70_older                             11637
# gdp_per_capita                            10746
# extreme_poverty                           40848
# cardiovasc_death_rate                     10761
# diabetes_prevalence                        8321
# female_smokers                            30914
# male_smokers                              31967
# handwashing_facilities                    56725
# hospital_beds_per_thousand                19022
# life_expectancy                            5227
# human_development_index                   10635
# excess_mortality                          99519
# dtype: int64

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.919700e+04   99194.000000        98184.000000  8.895300e+04
# mean   1.124722e+06    6072.262425         6083.795353  3.007728e+04
# std    7.666606e+06   37758.463944        37435.972295  1.795414e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.374000e+03       2.000000            7.714000  5.700000e+01
# 50%    1.441900e+04      75.000000           93.714000  4.230000e+02
# 75%    1.544450e+05     829.000000          870.000000  4.082000e+03
# max    1.899978e+08  905993.000000       826368.143000  4.082335e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  89109.000000         98184.000000             98670.000000
# mean     145.766802           131.539926             13882.078745
# std      797.217897           741.775158             25189.980677
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               272.535000
# 50%        2.000000             1.429000              1932.369500
# 75%       18.000000            14.571000             14805.335250
# max    18060.000000         14735.857000            184727.885000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           98667.000000                    97662.000000
# mean               76.578968                       76.711418
# std               200.620817                      158.654683
# min             -2153.437000                     -276.825000
# 25%                 0.227000                        1.316000
# 50%                 8.738000                       11.496000
# 75%                70.806500                       78.968750
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              88439.000000  ...     62295.000000           92382.000000
# mean                 304.108610  ...        13.422692             258.627553
# std                  544.503228  ...        19.966350             119.095459
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.347000  ...         0.600000             167.295000
# 50%                   54.754000  ...         2.200000             242.648000
# 75%                  335.194500  ...        21.200000             329.635000
# max                 5915.562000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         94822.000000    72229.000000  71176.000000
# mean              7.939718       10.574670     32.702259
# std               4.165228       10.476721     13.488423
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            46418.000000                84121.000000     97916.000000
# mean                50.814250                    3.026876        73.239068
# std                 31.757912                    2.457652         7.557990
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             92508.000000       3624.000000
# mean                  0.727192         18.218438
# std                   0.150353         35.742831
# min                   0.394000        -95.590000
# 25%                   0.602000          0.447500
# 50%                   0.748000          7.440000
# 75%                   0.848000         24.097500
# max                   0.957000        409.900000
#
# [8 rows x 55 columns]

# %%
df.date.min(), df.date.max()
# Out:
# ('2020-01-01', '2021-07-17')

# %% [markdown]
# ### Observations
#
# We have 60 features and 103143 entries from 231 countries. We have a lot of missing data in columns that will need further attention in working with it. We also have some negative values at columns new_cases, new_deaths, new_cases_per_million, I'll have to keep that in mind and investigate the cause of it; There are plenty of columns that has no use for us so I propobly should drop it to make working with data more efective. Finally we are working with data from 2020-01-01 -> 2021-07-17 and it also should be converted to datetime.
#
# #### Stringency index
#
# The nine metrics used to calculate the Stringency Index are: school closures; workplace closures; cancellation of public events; restrictions on public gatherings; closures of public transport; stay-at-home requirements; public information campaigns; restrictions on internal movements; and international travel controls.
#
# A higher score indicates a stricter response (i.e. 100 = strictest response). If policies vary at the subnational level, the index is shown as the response level of the strictest sub-region.
#
# It’s important to note that this index simply records the strictness of government policies. It does not measure or imply the appropriateness or effectiveness of a country’s response. A higher score does not necessarily mean that a country’s response is ‘better’ than others lower on the index.

# %% [markdown]
# # Cleaning up dataset

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')

# %%
cols_to_drop = ['continent', 'reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 'hosp_patients_per_million',
               'weekly_icu_admissions_per_million', 'tests_units', 'extreme_poverty', 'cardiovasc_death_rate',
               'diabetes_prevalence', 'handwashing_facilities', 'life_expectancy', 'human_development_index', 'excess_mortality']

# %%
df.drop(columns=cols_to_drop, inplace=True)
df.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'weekly_icu_admissions',
#        'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million',
#        'new_tests', 'total_tests', 'total_tests_per_thousand',
#        'new_tests_per_thousand', 'new_tests_smoothed',
#        'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case',
#        'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'female_smokers', 'male_smokers',
#        'hospital_beds_per_thousand'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103143 entries, 0 to 103142
# Data columns (total 45 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               103143 non-null  object
#  1   location                               103143 non-null  object
#  2   date                                   103143 non-null  object
#  3   total_cases                            99197 non-null   float64
#  4   new_cases                              99194 non-null   float64
#  5   new_cases_smoothed                     98184 non-null   float64
#  6   total_deaths                           88953 non-null   float64
#  7   new_deaths                             89109 non-null   float64
#  8   new_deaths_smoothed                    98184 non-null   float64
#  9   total_cases_per_million                98670 non-null   float64
#  10  new_cases_per_million                  98667 non-null   float64
#  11  new_cases_smoothed_per_million         97662 non-null   float64
#  12  total_deaths_per_million               88439 non-null   float64
#  13  new_deaths_per_million                 88595 non-null   float64
#  14  new_deaths_smoothed_per_million        97662 non-null   float64
#  15  weekly_icu_admissions                  951 non-null     float64
#  16  weekly_hosp_admissions                 1615 non-null    float64
#  17  weekly_hosp_admissions_per_million     1615 non-null    float64
#  18  new_tests                              46155 non-null   float64
#  19  total_tests                            45813 non-null   float64
#  20  total_tests_per_thousand               45813 non-null   float64
#  21  new_tests_per_thousand                 46155 non-null   float64
#  22  new_tests_smoothed                     53734 non-null   float64
#  23  new_tests_smoothed_per_thousand        53734 non-null   float64
#  24  positive_rate                          50221 non-null   float64
#  25  tests_per_case                         49591 non-null   float64
#  26  total_vaccinations                     18418 non-null   float64
#  27  people_vaccinated                      17512 non-null   float64
#  28  people_fully_vaccinated                14659 non-null   float64
#  29  new_vaccinations                       15370 non-null   float64
#  30  new_vaccinations_smoothed              32003 non-null   float64
#  31  total_vaccinations_per_hundred         18418 non-null   float64
#  32  people_vaccinated_per_hundred          17512 non-null   float64
#  33  people_fully_vaccinated_per_hundred    14659 non-null   float64
#  34  new_vaccinations_smoothed_per_million  32003 non-null   float64
#  35  stringency_index                       86245 non-null   float64
#  36  population                             102451 non-null  float64
#  37  population_density                     95774 non-null   float64
#  38  median_age                             92014 non-null   float64
#  39  aged_65_older                          90982 non-null   float64
#  40  aged_70_older                          91506 non-null   float64
#  41  gdp_per_capita                         92397 non-null   float64
#  42  female_smokers                         72229 non-null   float64
#  43  male_smokers                           71176 non-null   float64
#  44  hospital_beds_per_thousand             84121 non-null   float64
# dtypes: float64(42), object(3)
# memory usage: 35.4+ MB

# %% [markdown]
# # Answering Questions

# %% [markdown]
# ## 0. What is total number of Covid cases, tests made and vaccinated people?

# %% [markdown]
# ### Total number of covid cases

# %%
total_cases = df.groupby('iso_code')['total_cases'].last().sum()
total_cases
# Out:
# 603408677.0

# %% [markdown]
# ### Total number of tests made

# %%
total_tests = df.groupby('iso_code')['total_tests'].last().sum()
total_tests
# Out:
# 2587356722.0

# %% [markdown]
# ### Total number of vaccinated people

# %%
total_vac = df.groupby('iso_code')['total_vaccinations'].last().sum()
total_vac
# Out:
# 11322906681.0

# %% [markdown]
# ## 1. How dense population is in every country?

# %%
df.groupby('iso_code')['population_density'].first()
# Out:
# iso_code
# ABW    584.800
# AFG     54.422
# AGO     23.890
# AIA        NaN
# ALB    104.871
#         ...
# WSM     69.413
# YEM     53.508
# ZAF     46.754
# ZMB     22.995
# ZWE     42.729
# Name: population_density, Length: 231, dtype: float64

# %% [markdown]
# ### Sanity check

# %%
df.loc[df.iso_code == 'ABW',['population_density']].head()
# Out:
#       population_density
# 4753               584.8
# 4754               584.8
# 4755               584.8
# 4756               584.8
# 4757               584.8

# %%
density_df = df.groupby('iso_code')[['population_density', 'location']].first().reset_index()
density_df.head()
# Out:
#   iso_code  population_density     location
# 0      ABW             584.800        Aruba
# 1      AFG              54.422  Afghanistan
# 2      AGO              23.890       Angola
# 3      AIA                 NaN     Anguilla
# 4      ALB             104.871      Albania

# %%
density_df.population_density.min(), density_df.population_density.max()
# Out:
# (0.137, 20546.766)

# %%
df.population_density.describe()
# Out:
# count    95774.000000
# mean       388.720811
# std       1810.480729
# min          0.137000
# 25%         36.253000
# 50%         83.479000
# 75%        209.588000
# max      20546.766000
# Name: population_density, dtype: float64

# %%
fig = px.choropleth(density_df, locations='iso_code', color='population_density',
                   hover_name='location', projection='natural earth',
                   title='Population Density',
                   range_color=(0,500),
                   color_continuous_scale='greens'
                   )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Observations
#
# There are few countries that has a massive population density. But those countries are independent regions in other countries in example Monaco and Makau. Plotly by default are not including those regions in map.
#
# ***TO DO:*** find a better GeoJSON

# %% [markdown]
# ## 2. What is Median age in every country and how does it look compared to others?

# %%
age_df = df.groupby('iso_code')[['location', 'median_age']].first().reset_index()
age_df.head()
# Out:
#   iso_code     location  median_age
# 0      ABW        Aruba        41.2
# 1      AFG  Afghanistan        18.6
# 2      AGO       Angola        16.8
# 3      AIA     Anguilla         NaN
# 4      ALB      Albania        38.0

# %%
age_df.describe()
# Out:
#        median_age
# count  191.000000
# mean    30.303665
# std      9.093852
# min     15.100000
# 25%     22.100000
# 50%     29.600000
# 75%     38.700000
# max     48.200000

# %%
fig = px.choropleth(age_df, locations='iso_code', color='median_age',
                   hover_name='location', projection='orthographic',
                   title='Population Density',
                   range_color=(15,49),
                   color_continuous_scale='greens'
                   )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## 3. How covid progressed by total cases, new cases, total deaths, new deaths?

# %% [markdown]
# ### Covid Progression by Total Cases

# %%
df.sort_values('date', inplace=True)

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'total_cases', 'date']], locations='iso_code',
                    color='total_cases',
                    animation_frame='date', 
                    title='Total Cases of Covid19',
                    height=750,
                    color_continuous_scale='greens'
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Covid Progression by New Cases

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'new_cases_smoothed', 'date']], locations='iso_code',
                    color='new_cases_smoothed',
                    animation_frame='date', 
                    title='New Cases of Covid19',
                    height=750,
                    color_continuous_scale='greens'
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Covid Progression by Total Deaths

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'total_deaths', 'date']], locations='iso_code',
                    color='total_deaths',
                    animation_frame='date', 
                    title='Total Deaths of Covid19',
                    height=750,
                    color_continuous_scale='greens'
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Covid Progression by New Deaths

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'new_deaths_smoothed', 'date']], locations='iso_code',
                    color='new_deaths_smoothed',
                    animation_frame='date', 
                    title='New Deaths of Covid19',
                    height=750,
                    color_continuous_scale='greens'
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## 4. How testing rate changed during the pandemic?

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'new_tests', 'date']], locations='iso_code',
                    color='new_tests',
                    animation_frame='date', 
                    title='New Tests of Covid19',
                    height=750,
                    color_continuous_scale='greens'
)

#fig.update(layout_coloraxis_showscale=False)
fig.show()

# %% [markdown]
# ## 5. How tests per case changed in Lithuania, Japan and USA.

# %%
df.sort_index(inplace=True)
df.head()

# %%
df.columns

# %%
ds = df.loc[(df.iso_code == 'JPN') | (df.iso_code == 'USA') | (df.iso_code == 'LTU'), ['date', 'iso_code', 'tests_per_case']]

# %%
fig = px.line(ds, x='date', y='tests_per_case', color='iso_code')

fig.update_xaxes(
    dtick="M1",
    tickformat='%b\n%Y'
)

fig.show()

# %% [markdown]
# ## 6. Vaccination progess, how it change?

# %%
vac = df.groupby('date')['new_vaccinations'].agg(['sum'])
vac.reset_index(inplace=True)

vac.rename(columns={'sum':'Vaccines'}, inplace=True)
vac = vac[vac.Vaccines != 0]
vac.head()

# %%
fig = px.line(vac, x='date', y='Vaccines')

fig.update_xaxes(
    dtick="M1",
    tickformat='%b\n%Y'
)

fig.show()

# %% [markdown]
# ## 7. How strictly goverments responded with restrictions?

# %%
fig = px.choropleth(df.loc[:,['iso_code', 'stringency_index', 'date', 'location']], locations='iso_code', color='stringency_index',
                   hover_name='location', projection='natural earth',
                   title='Stringency Index',
                   range_color=(0,100),
                   color_continuous_scale='greens'
                   )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## 8. Does countries that have more smoking people suffer more from covid?

# %%
df.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'weekly_icu_admissions',
#        'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million',
#        'new_tests', 'total_tests', 'total_tests_per_thousand',
#        'new_tests_per_thousand', 'new_tests_smoothed',
#        'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case',
#        'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'female_smokers', 'male_smokers',
#        'hospital_beds_per_thousand'],
#       dtype='object')

# %%
smokers = df.groupby('iso_code')[['female_smokers', 'male_smokers', 'total_cases_per_million']].last()

# %%
smokers = smokers.dropna().sort_values('total_cases_per_million')

# %%
smokers['total_smokers'] = smokers['female_smokers'] + smokers['male_smokers']

# %%
smokers.loc[:,['total_cases_per_million', 'total_smokers']].corr()

# %%
smokers.head(10), smokers.tail(10)

# %% [markdown]
# ### Observations
#
# Looking at correlation between total_smokers and total_cases_per_million we can se weak correlation, which implies that there could be some small proff that countries that have more people that smoke has a greater risk having a more covid cases. That being said correlation is not a perfect way to determen causality and looking at top 10 and bottom 10 countries by covid cases per million people we can see that percentage of people that smoke varies a little, but are very similar.

# %% [markdown]
# ## 9. How gdp_per_capita and meadian age correlates with total cases?

# %%
gdp_age = df.groupby('iso_code')[['gdp_per_capita', 'median_age', 'total_cases_per_million']].last()
gdp_age = gdp_age.dropna().sort_values('total_cases_per_million')
gdp_age.head(10), gdp_age.tail(10)
# Out:
# (          gdp_per_capita  median_age  total_cases_per_million
#  iso_code
#  TZA             2683.304        17.7                    8.521
#  FSM             3299.464        23.0                    8.694
#  VUT             2921.909        23.1                   13.023
#  WSM             6021.557        22.0                   15.120
#  KIR             1981.132        23.2                   16.744
#  SLB             2205.923        20.8                   29.117
#  CHN            15308.712        38.7                   64.128
#  NER              926.000        15.1                  230.226
#  YEM             1479.147        20.3                  233.924
#  TCD             1768.153        16.7                  302.206,
#            gdp_per_capita  median_age  total_cases_per_million
#  iso_code
#  NLD            48472.545        43.2               106022.904
#  SWE            46949.283        41.0               108353.079
#  URY            20551.409        35.6               109027.854
#  LUX            94277.965        39.7               116232.891
#  SVN            31400.840        44.5               124183.475
#  MDV            15183.616        30.6               140259.221
#  CZE            32605.906        43.3               156020.712
#  BHR            43290.705        32.4               157380.510
#  MNE            16409.288        39.1               160210.298
#  SYC            26382.287        36.2               175249.136)

# %%
gdp_age.corr()
# Out:
#                          gdp_per_capita  median_age  total_cases_per_million
# gdp_per_capita                 1.000000    0.651889                 0.449003
# median_age                     0.651889    1.000000                 0.602184
# total_cases_per_million        0.449003    0.602184                 1.000000

# %% [markdown]
# ### Observations
#
# By Spearman correlation we can see that medium to strong positive dependancy between median age and total cases per million and weaker positive dependency between gdp per capita and total cases per million. Once again correlation is not a perfect way to determen causality but lookit at 10 best (least cases) and worst(most cases) we can see tendencies that yourger median age results in smaller number of cases.

# %% [markdown]
# # Final Toughts

# %% [markdown]
# To begin with I want to say thank you for [Alexa](https://www.kaggle.com/saumya5679), who provided this wonderful [dataset](https://www.kaggle.com/saumya5679/covid19-timeline-analysis) and who allowed me to practise EDA and data visualisation with Plotly.
#
# 1. As expected there is a rise of cases till summer of 2020 then cases starts to drop till it reaches plateu for few months and around Autunm (or Fall if you are American) total cases stats to increase again.
# 2. New tests amount increases at the middle of covid and starts to drop in 2021 because people is finishing vaccinations and gaining immunity resulting in no tests needed.
# 3. Vaccinations ramping up tremendously at the start and then plateus with regular spikes as people are getting there vaccines. The total vacines should drop later on because most people will have there vaccines and less population will remain unvaccinated.
# 4. As expected younger median age countries has lower total cases per million people with correlation 0.6, gdp has lower correlation with around 0.45. Which implies that this assumption was correct.
